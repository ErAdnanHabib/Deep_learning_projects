# %%
import cv2 as cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread("no_use_img/tim-gouw-VvQSzMJ_h0U-unsplash.jpg")
img2=cv2.imread("no_use_img/wallpaperflare.com_wallpaper (2).jpg")

# %%
 plt.imshow(img1)

# %%
 plt.imshow(img2)
